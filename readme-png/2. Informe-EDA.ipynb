# %% [markdown]
# ### Análisis Exploratorio de Datos para Business Payments
#
# **Informe EDA:**
#
# Elaborar un informe detallado en formato markdown que resuma los hallazgos más importantes del EDA. Este informe debe incluir visualizaciones relevantes y conclusiones clave para facilitar la comprensión del conjunto de datos y sus principales características.

# %% [markdown]
# ## 1.   Carga y exploración inicial del dataset **Cash Request**
#
# Distruimos las transacciones por estado

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Insigths:
# Observamos un **estado dominante: "money_back"** (con 16,397 transacciones) que representa la mayoría de las operaciones. Esto puede indicar un alto volumen de devoluciones o reembolsos procesados por el sistema.
#
# El segundo estado más observado es el "rejected" (6,568 transacciones), lo que sugiere una notable cantidad de rechazos de solicitudes o intentos de pago.
#
# El resto de los estados muestran números considerablemente más bajos.
#
#
# Por lo tanto tenemos:
# * Altas tasas de "money_back" y "rejected":
# Estos estados sugieren posibles problemas operativos relacionados con devoluciones y rechazos de transacciones, que podría deberse a errores del usuario, fallos técnicos o políticas restrictivas del servicio.
#
# * Los estados menos frecuentes:
# Los estados menos representados como "canceled" o "active" pueden corresponder a acciones más específicas o etapas avanzadas del ciclo de transacción.
#
# * Vamos a investigar patrones en "money_back" y "rejected": cohortes, temporalidad, o condiciones que expliquen estos valores dominantes. Asi como profundizar en las causas de las devoluciones y rechazos.
# Además de evaluar si estos estados afectan ingresos, frecuencia de uso o tasas de incidentes.

# %% [markdown]
# ## Ahora analizamos la distribución temporal de transacciones

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Insights:
#
# Observamos un **crecimiento cradual durante los primeros meses** (de noviembre de 2020 a mayo), se observa un crecimiento moderado en el número de transacciones, quizás un puede reflejar un período de adopción inicial por parte de los usuarios.
#
# **Incremento acelerado desde junio hasta septiembre**, indicando un posible crecimiento en la base de usuarios, campañas exitosas o mejoras en los servicios.
#
# El **punto más alto ocurre en octubre**, con un número significativamente mayor de transacciones (~8,000). Esto podría estar relacionado con eventos promocionales, estacionalidad o un cambio significativo en las políticas de la empresa.
#
#
# En noviembre, el número de transacciones cae drásticamente,  podría deberse a falta de datos completos para el mes de noviembre o factores internos como problemas técnicos o externos como estacionalidad negativa. O salida del Covid?
#
#
# ## Por lo tanto, tenemos:
#
# * Crecimiento General: La tendencia global muestra un crecimiento continuo en el #transacciones, lo cual es positivo y puede reflejar una mayor adopción o confianza de los usuarios en el servicio.
#
# * Pico de Octubre: Este punto requiere análisis adicional para identificar las razones detrás del aumento abrupto: ¿Hubo promociones especiales o lanzamientos de productos? ¿Se expandieron los servicios a nuevos mercados?
# Identificar las causas puede ser clave para replicar este éxito en el futuro.
#
# * Caída en Noviembre: Si los datos son completos, podría reflejar una caída preocupante en la actividad y requerir un análisis adicional para determinar si hubo problemas operativos o cambios en el comportamiento de los usuarios.

# %% [markdown]
# ## Ahora creamos cohortes mensuales

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Métricas Iniciales para el Proyecto
#
# Las métricas iniciales a calcular y analizar para comenzar el proyecto son las siguientes:
#
#
# * 1. **Frecuencia de Uso del Servicio:**
# Analizar con qué frecuencia los usuarios de cada cohorte utilizan los servicios de adelanto de efectivo de Business Payments a lo largo del tiempo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Observaciones:
#
# Tenemos 18,800 filas (transacciones realizadas por usuarios específicos en distintas cohortes)
#
# - user_id: Identificador único del usuario.
# - cohort: Mes y año de incorporación del usuario.
# - transaction_count: Número de transacciones realizadas por cada usuario en una cohorte específica.
#
# * Calculamos el promedio de transacciones por usuario dentro de cada cohorte:
# Los valores van desde 1.00 (cohortes como noviembre de 2019 y noviembre de 2020) hasta 1.31 (cohorte julio de 2020), indicando variaciones significativas en la interacción.
#
# * El gráfico muestra una tendencia general de aumento y posterior descenso en la frecuencia de uso
#
# * Analizando la frecuencia promedio de transacciones por usuario dentro de cada cohorte observamos estos patrones:
#
#     * Incremento Notable en Frecuencia (2020-Q2 a 2020-Q3):
#
#     * Las cohortes de junio y julio de 2020 muestran los picos más altos de uso promedio (1.31 y 1.30 respectivamente). Esto podría estar relacionado con factores externos como la estacionalidad o cambios en la oferta del servicio.
#
#     * Descenso Gradual hacia 2020-Q4:
#     A partir de agosto de 2020, se observa una disminución en la frecuencia promedio, llegando nuevamente al nivel inicial (1.00) para noviembre de 2020.
#
#     * Cohortes Estables (2019-Q4 y 2020-Q1):
#     Las cohortes de noviembre y diciembre de 2019, junto con las del primer trimestre de 2020, muestran una interacción más consistente, con promedios alrededor de 1.10 - 1.14.
#
#
# ## Conclusiones:
# Mayor Interacción en 2020-Q2 a Q3:
#
# El crecimiento observado en el segundo y tercer trimestre de 2020 podría estar impulsado por factores externos, como una mayor demanda del servicio o estrategias específicas de retención.
#
# Disminución hacia 2020-Q4: La caída en la frecuencia promedio puede indicar una saturación del servicio, un cambio en las necesidades de los usuarios o falta de campañas de fidelización. Recomendamos investigar esta tendencia.
#
# Segmentación por Cohortes con Alto Potencial: Cohortes como junio y julio de 2020 (mayor uso promedio) podrían ser puntos de referencia para diseñar estrategias que reactiven cohortes con menor interacción.
#
#
# Como próximo paso, vamos a realizar un análisis más detallado de las cohortes, considerando variables como status, amount y transfer_type.
# También podriamos implementar estrategias de retención para cohortes con menor interacción promedio, tomando en cuenta incentivos personalizados.

# %% [markdown]
# * 2. **Tasa de Incidentes**: Determinar la tasa de incidentes, especialmente aquellos relacionados con problemas de pago, en cada cohorte. Identificar variaciones significativas entre cohortes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Primeras observaciones** :
#
# Se utilizó un gráfico de barras apiladas para mostrar las tasas de incidentes por cohorte, desglosando el total en problemas de pago y otros incidentes.
#
#
# * Identificamos estos patrones:
#
#     * Cohortes con Alta Tasa de Incidentes:
#
#         Enero de 2020 (50.22%) y junio de 2020 (43.99%) presentan las tasas totales de incidentes más altas. Estos meses coinciden con una mayor proporción de problemas de pago (8.30% y 2.58% respectivamente).
#
#
#     * Variación en Problemas de Pago:
#
#         La tasa de problemas de pago disminuye significativamente después de enero de 2020, mostrando valores más bajos durante los meses de primavera y verano. Sin embargo, octubre y noviembre de 2020 muestran un incremento en problemas de pago (4.66% y 5.71%).
#
#
#     * Tendencia General:
#
#         A lo largo del período analizado, hay una ligera tendencia descendente en las tasas totales de incidentes. Esto podría indicar mejoras operativas en la gestión de transacciones o mayor estabilidad del sistema.
#
#     * Cohortes con Tasa Baja:
#
#         Marzo y abril de 2020 destacan con tasas bajas de incidentes totales (30.74% y 27.12%) y problemas de pago (1.23% y 2.15%). Este período puede ser un punto de referencia para mejores prácticas.
#
#
# **Ahora pasamos a la interpretación del gráfico**:
#
# * Las barras rojas representan el porcentaje de incidentes totales en cada cohorte.
# * Las barras naranjas apiladas sobre las rojas representan el porcentaje específico de problemas de pago dentro del total.
#
#
# ## * Conclusiones:
#
# * Reducción de Problemas de Pago:
# Aunque los problemas de pago representan un menor porcentaje del total de incidentes en la mayoría de las cohortes, sus valores elevados en ciertos meses (e.g., enero 2020) indican la necesidad de mejorar el manejo de débitos directos, posiblemente mediante validaciones más estrictas o recordatorios para los usuarios.
#
# * Cohortes de Alto Riesgo:
# Las cohortes de enero de 2020 y junio de 2020 necesitan ser investigadas más a fondo para identificar las causas de los altos incidentes totales.
#
# * Estrategias de Mejora:
# Implementar campañas de concientización para reducir problemas de pago (e.g., correos de recordatorio para usuarios).
# Analizar cohortes exitosas como marzo y abril de 2020, replicando estrategias que contribuyeron a tasas bajas de incidentes.
#
# * Monitoreo Continuo:
# Realizar un seguimiento constante de las tasas de incidentes por cohorte para detectar problemas emergentes de manera temprana.
#
#
# * Próximo Paso:
# Vamos a explorar variables adicionales como amount, transfer_type o payment_method para identificar factores asociados con incidentes. También podriamos implementar (si tuvieramos posibilidad de más tiempo) pruebas A/B en cohortes futuras para evaluar la efectividad de nuevas estrategias de mitigación de incidentes.

# %% [markdown]
# * 3. **Ingresos Generados por Cohorte**: Calcular el total de ingresos generados por cada cohorte a lo largo del tiempo para evaluar el impacto financiero del comportamiento de los usuarios.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * **Primeras observaciones de los ingresos totales generados por cada cohorte a lo largo del tiempo**:
#
# * Patrones Identificados:
#
#     * Incremento Sostenido de Ingresos:
#         A partir de abril de 2020, se observa un aumento significativo en los ingresos, alcanzando su punto máximo en octubre de 2020 con $559,339 generados. Este crecimiento indica un aumento en el volumen de transacciones o en el tamaño promedio de las transacciones realizadas.
#
#     * Cohortes con Bajos Ingresos:
#         Las cohortes iniciales, como noviembre de 2019 ($1) y noviembre de 2020 ($10,710), presentan ingresos significativamente bajos. Esto podría deberse a una menor cantidad de usuarios activos o a una menor adopción del servicio en estos períodos.
#
#     * Cohortes Destacadas:
#         Junio de 2020 ($246,026), julio de 2020 ($328,187) y septiembre de 2020 ($336,507) son meses de alto desempeño, marcando una fase de crecimiento acelerado.
#
#     * Disminución en Noviembre de 2020:
#         Los ingresos caen drásticamente en noviembre de 2020. Esto puede indicar una disminución en la actividad del usuario, cambios en políticas o en la oferta del servicio, o una menor cantidad de datos disponibles para este período.
#
#
#     * Comparativo entre cohortes:
#         El gráfico de barras permite observar de manera clara el crecimiento y las fluctuaciones en los ingresos entre cohortes.
#
#
# ## Conclusiones:
#
# * Crecimiento Consistente:
# Las cohortes de abril a octubre de 2020 muestran un crecimiento consistente en ingresos, lo que puede estar asociado con una mayor adopción del servicio o una expansión en el mercado objetivo. Podríamos analizar las campañas de marketing y las estrategias aplicadas durante este período para replicarlas en el futuro.
#
# * Análisis de Cohortes con Bajos Ingresos:
# Noviembre de 2019 y noviembre de 2020 presentan ingresos muy bajos. Podríamos investigar las causas, como posibles inicios de servicio, cambios estacionales o errores en los datos, para entender mejor estas anomalías.
#
# * Impacto Financiero de las Cohortes con Altos Ingresos:
# Cohortes como julio y septiembre de 2020 aportaron ingresos significativos al negocio. Focalizarse en el comportamiento de estas cohortes (e.g., frecuencia de transacciones, montos promedio) nos podría ayudar a revelar patrones útiles para captar nuevos usuarios.
#
# * Planes a Futuro:
# Realizar una segmentación por tipo de cliente para entender mejor qué usuarios aportaron más ingresos.
# Podríamos monitorear de cerca la caída en ingresos en noviembre de 2020 y evaluar medidas correctivas.
#
# * Cómo próximo paso:
# Podríamos hacer un análisis de ingresos promedio por usuario para evaluar contribuciones individuales/agruparlos.
# Relacionar los ingresos con tasas de incidentes o problemas de pago para evaluar cómo impactan estos factores en el desempeño financiero.
# Explorar variaciones estacionales o tendencias macroeconómicas que puedan explicar patrones observados en los ingresos.

# %% [markdown]
# 4. **Métricas Acumuladas por Cohorte**: Proponer y calcular métricas acumuladas que proporcionen perspectivas adicionales para la extracción de insights accionables.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Analizamos las siguientes métricas acumuladas por cohorte:
#
# * Ingresos Totales Acumulados ($): Suma de los ingresos generados por cada cohorte desde su inicio hasta el mes actual.
# * Número de Transacciones Acumuladas: Total de transacciones completadas desde el inicio de cada cohorte hasta el mes actual.
# * Porcentaje Acumulado de Ingresos sobre el Total (%):Representa la contribución acumulada de cada cohorte al ingreso total. Esto ayuda a identificar las cohortes más relevantes para los ingresos generales.
#
#
#
# * Primeras observaciones:
#
#     * **Crecimiento de Ingresos y Transacciones**
#
#         * Incremento Acumulado Constante:
#             Los ingresos acumulados muestran un crecimiento exponencial, alcanzando $1,982,818 en noviembre de 2020.
#             El número de transacciones acumuladas también crece, llegando a 23,970 transacciones en total.
#
#         * Contribución Clave de las Cohortes de Verano:
#             Junio, julio y agosto de 2020 representan un punto de inflexión, donde los ingresos acumulados crecen rápidamente.
#             Estas cohortes contribuyen de forma significativa al total:
#             Junio 2020: $246,026 (12.40% del total).
#             Julio 2020: $328,187 (16.55% del total).
#             Agosto 2020: $287,633 (14.52% del total).
#
#
#     * **Contribución Porcentual Acumulada**
#
#         * Cohortes Más Relevantes:
#             Para octubre de 2020, el 99.46% del ingreso total había sido generado, destacando la importancia de cohortes previas.
#             Las cohortes de inicio tardío, como noviembre de 2020, tienen una contribución mínima al ingreso acumulado (0.54% del total).
#
#         * Disminución en las Tasas de Crecimiento Relativo:
#             Aunque los ingresos continúan creciendo, el porcentaje incremental generado por cohortes más recientes es menor, sugiriendo saturación o estabilización.
#
#
#     * **Distribución de Transacciones**
#
#         * Transacciones Altas en Cohortes Tardías:
#             La cohorte de octubre de 2020 muestra un salto significativo en transacciones acumuladas, con 23,830 transacciones hasta noviembre.
#             Este aumento coincide con el mayor ingreso acumulado registrado.
#
#     * Patrones Destacados
#         * La línea roja muestra un comportamiento sigmoidal, indicando que la mayoría de los ingresos provienen de cohortes intermedias.
#         * Las barras reflejan la rápida acumulación de ingresos en los meses de verano (junio-agosto 2020).
#
# ## Conclusiones:
#
# * Contribuciones Clave:
# Las cohortes de mediados de 2020 (junio-agosto) son las más relevantes para los ingresos acumulados y representan un alto porcentaje del total.
# Estas cohortes podrían servir como modelo para estrategias de adquisición y retención de clientes.
#
# * Diversificación
# El 71% de los ingresos acumulados se generan antes de septiembre de 2020, lo que indica una dependencia significativa de cohortes más antiguas.
# Es clave diversificar ingresos en cohortes más recientes o crear estrategias para aumentar su contribución.
#
# * Optimización (problales)
#     * Estrategias de Retención: Aumentar el tiempo de vida útil de clientes adquiridos en cohortes iniciales.
#     * Aceleración de Cohortes Nuevas: Implementar campañas de marketing para incrementar la adopción y contribución de cohortes tardías.
#     * Monitoreo Continuo: Realizar un seguimiento mensual de las métricas acumuladas para evaluar cambios en el comportamiento del usuario.
#     * Por rendimiento: Analizar cohortes específicas con alto rendimiento (e.g., junio-julio 2020) para identificar factores de éxito. Explorar las características de clientes o transacciones con mayor impacto en ingresos acumulados. Extender el análisis para incluir métricas de margen o costo por cohorte para obtener un panorama financiero completo.

# %% [markdown]
# ---
# ---
# ## 2.   Carga y exploración inicial del dataset **Fees**
#
# Distruimos las transacciones por tipo de tarifa

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Distribución de tipos de tarifas (type):
#
# instant_payment es el tipo más común, representando aproximadamente el 53% del total de tarifas.
# Esto nos podría sugerir que los usuarios prefieren opciones de pago inmediato sobre otras modalidades.
#
#
# * Estadísticas Generales del Dataset:
#
# El cohorte más destacado es Octubre 2020, dado que es el mes con mayor frecuencia de uso, mayores ingresos y mayor tasa de incidentes:
#     Transacciones: 10,766
#     Ingresos: $53,835 (51.1% del total acumulado).
#     Tasa de incidentes: 6.51%, que es alta comparativamente.
#     Ingresos acumulados: $105,310.

# %% [markdown]
# * También observamos es que hay columnas con datos nulos significativos, tales como category, to_date y from_date, paid_at(entre 26% y 89% de valores nulos), lo que podria indicar un problema de integridad, analizaremos si es relevante para el modelo o negocio, y comentaremos la relación entre category y las incidencias por ejemplo.
# Analizaremos estos puntos con más detalle en el punto **3. Análisis de Calidad de Datos**

# %% [markdown]
# *  Fechas importantes (from_date, to_date, paid_at):
#
#     Las estadísticas revelan períodos y valores coherentes:
#
#     from_date:  Rango: 27 de mayo de 2020 a 2 de enero de 2021.
#                 Mediana: 25 de septiembre de 2020.
#
#     to_date:    Rango: 9 de junio de 2020 a 17 de enero de 2021.
#                 Mediana: 29 de octubre de 2020.
#
#     paid_at:    Rango: 23 de junio de 2020 a 12 de febrero de 2021.
#                 Mediana: 2 de noviembre de 2020.
#
#
#     * ¿Qué nos dicen estos datos?
#         - **Temporalidad estratégica**: Todo gira en torno al segundo semestre de 2020. Esto podría indicar que el sistema operó con mayor intensidad en este período.
#         - **Armonía operativa**: Las fechas medianas caen dentro de un margen coherente, lo que sugiere procesos bien alineados y predecibles.

# %% [markdown]
# * Posibles próximos pasos considerados:
#
#     - Investigar la relevancia de las columnas con alta cantidad de nulos.
#     - Imputar valores o eliminar columnas dependiendo del análisis.
#     - Comparar el desempeño de distintas cohortes más allá de octubre de 2020.
#     - Identificar patrones de crecimiento o estancamiento.
#     - Gráfico temporal para ver evolución de ingresos por mes.
#     - Tasa de incidentes o pagos no completados por tipo y cohorte.

# %% [markdown]
# ---
# **INSIGHTS RELEVANTES**:
# - Cohorte con mayor frecuencia de uso: 2020-10 (10766 transacciones)
# - Cohorte con mayor tasa de incidentes: 2020-10 (6.51%)
# - Cohorte con mayores ingresos: 2020-10 ($53,835.00)
# - Total de ingresos acumulados: $105,310.00
# ---

# %% [markdown]
# **Iniciamos el análisis avanzado de datos para Business Payments, centrandonos en insights accionables y cohortes, con el objetivo de mejorar la comprensión del comportamiento de las transacciones y optimizar los servicios financieros ofrecidos.**

# %% [markdown]
# * Definimos y analizamos cohortes:
#
# Agrupamos según el período en que realizaron los primeros adelanto de efectivo.
# Estudiamos la evolución temporal de métricas dentro de estas cohortes.
#
# Calculamos y analizamos las métricas clave solicitadas:
#
# ---
#
# * **Frecuencia de Uso del Servicio**: Analizar con qué frecuencia los usuarios de cada cohorte utilizan los servicios de adelanto de efectivo de Business Payments a lo largo del tiempo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Insights:
#     - Rango de Cohortes: Desde noviembre de 2019 hasta noviembre de 2020.
#     - Promedio Global de Transacciones: Aprox 1.15 transacciones por usuario.
#
# * Las cohortes de verano (junio-agosto de 2020) muestran un incremento sostenido en el promedio de transacciones, alcanzando un pico en julio con 1.31 transacciones por usuario.
# * Las cohortes iniciales (noviembre de 2019 a febrero de 2020) tienen un promedio más bajo, rondando 1.1 transacciones.
#
# * Interpretando el gráfico se deduce:
#     - Una tendencia creciente. La frecuencia promedio aumenta gradualmente desde inicios de 2020, alcanzando su punto máximo en julio de 2020.
#     - Una disminución posterior. A partir de septiembre, se observa un descenso leve pero constante.
#
#
# * Observaciones Clave
#     - Usuarios recientes vs. antiguos: Los usuarios de cohortes más recientes (noviembre de 2020) tienen frecuencias similares a las cohortes más antiguas, indicando estabilidad en el uso inicial del servicio.
#     - Factores estacionales: Deducimos que los picos de transacciones en verano pueden deberse a factores externos como mayor tiempo libre o campañas promocionales.
#
#     - Aumento en transacciones durante junio-agosto de 2020, ver para replicar estrategias exitosas.
#     - Optimizar cohortes recientes: Identificar barreras que limitan el incremento de transacciones en cohortes recientes (noviembre de 2020).
#     - Campañas personalizadas: Implementar incentivos específicos para retener y aumentar el uso en cohortes que muestran menor frecuencia promedio.
#
#
# ### Conclusión:
# El análisis sugiere patrones estacionales y una tendencia creciente en las transacciones por cohorte hasta mediados de 2020, de aquí podriamos usar estos insights pueden ser utilizados para mejorar estrategias de retención y captación de usuarios.

# %% [markdown]
# ---
#
# * **Tasa de Incidentes**: Identificar problemas de pago u otros incidentes dentro de cada cohorte.

# %% [markdown]
# Vamos a identificar variaciones significativas en el comportamiento entre cohortes.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Se identificaron **1,194 transacciones rechazadas** entre las cohortes analizadas.
#
#     Cohorte     Tasa de Incidentes (%)
#     2020-05	    -
#     2020-06	    0.26
#     2020-07	    1.61
#     2020-08	    5.57
#     2020-09	    6.23
#     2020-10	    6.51
#     2020-11	    3.75
#
#
# Primeras observaciones:
#
# - Incremento progresivo: La tasa de incidentes aumenta significativamente desde junio de 2020 (0.26%) hasta alcanzar su pico en octubre de 2020 (6.51%).
# - Disminución posterior: En noviembre, la tasa de incidentes baja al 3.75%.
#
# - Como ya mencionamos antes, la cohorte 2020-10 destaca con la mayor proporción de incidentes.
#
# ## Conclusión:
#
# Tendencia al alza:
# La tasa de incidentes creció de manera constante desde junio hasta octubre de 2020, lo que podría estar relacionado con factores externos como
# - Cambios en políticas de pago o validación.
# - Aumento en el volumen de transacciones rechazadas por problemas técnicos.
#
# Cohortes críticas:
# Las cohortes de agosto a octubre de 2020 requieren mayor análisis para identificar causas específicas de su alta tasa de incidentes.
#
# Reducción en noviembre:
# La disminución en noviembre podría sugerir ajustes efectivos en los procesos de pago o menor volumen de transacciones.

# %% [markdown]
# ---
# * **Ingresos por Cohorte**: Evaluar los ingresos acumulados por cohorte en el tiempo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Primeras observaciones**
#
# * Incremento Sostenido en Ingresos:
#     * Los ingresos generados por cohorte muestran un crecimiento constante desde mayo de 2020 hasta octubre de 2020.
#     * Este patrón indica una mejora progresiva en la capacidad de monetización de las cohortes.
#
# * Cohorte Destacada:
#     * Octubre de 2020 generó $53,835, lo que representa un pico significativo en comparación con las cohortes previas.
#     * Es importante analizar las características de esta cohorte (e.g., comportamiento de los usuarios, estrategias implementadas) para identificar factores de éxito.
#
# * Declive en Noviembre 2020:
#     * La cohorte de noviembre muestra una caída abrupta, generando solo $1,335.
#     * Esto podría deberse a un menor tiempo de madurez de la cohorte, un cambio en las estrategias de adquisición o una disminución en la actividad de los usuarios.
#
# * Crecimiento Explosivo en Agosto-Octubre:
#     * El periodo entre agosto y octubre refleja una aceleración significativa en los ingresos generados.
#
# * Diferenciación por Cohortes:
#     El contraste entre el desempeño de las cohortes más antiguas y las más recientes destaca la importancia de un análisis enfocado en cohortes individuales.
#
# ## Conclusiones:
#
# * Crecimiento Progresivo:
# Las cohortes de verano y otoño (junio-octubre 2020) fueron las más lucrativas, alcanzando su punto máximo en octubre.
# * Inconsistencias en Cohortes Nuevas: La cohorte de noviembre generó ingresos significativamente menores, lo que indica la necesidad de investigar posibles causas internas (e.g., cambios en la estrategia) o externas (e.g., menor demanda).
# * Podríamos analizar detalladamente las estrategias aplicadas en las cohortes de alto desempeño (agosto-octubre).
# * También implementar mejoras en la experiencia del usuario y estrategias de retención para impulsar el desempeño de cohortes más recientes.
# * Además de realizar un seguimiento constante del desempeño financiero de cada cohorte para identificar patrones emergentes y ajustar estrategias en tiempo real.

# %% [markdown]
# * **Métricas acumuladas**: Proponer indicadores adicionales para enriquecer el análisis.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Primeras observaciones:
#
#     * Crecimiento Financiero
#         * El ingreso acumulado muestra un aumento consistente, alcanzando un máximo de $105,310 en noviembre de 2020.
#         * El mayor salto en ingresos se observa en cohortes posteriores a julio de 2020, marcando un crecimiento acelerado.
#
#     * Crecimiento de Transacciones
#         * Las transacciones acumuladas siguen una trayectoria similar, alcanzando un total de 21,061 transacciones en noviembre de 2020.
#         * Las cohortes de junio y julio 2020 reflejan un incremento significativo en el volumen de transacciones (769 y 1,619 transacciones, respectivamente), contribuyendo de forma crucial al crecimiento acumulado.
#
#     * Progresión de Cohortes
#         * Cohortes iniciales como mayo de 2020 tienen menor impacto en el total acumulado, tanto en ingresos ($80) como en transacciones (16).
#         * Cohortes intermedias (agosto y septiembre de 2020) consolidan la mayoría de las transacciones e ingresos acumulados, representando puntos clave para estrategias futuras.
#
#     * Exponencialidad:
#         * Se observa un comportamiento exponencial en ambas métricas a medida que las cohortes más recientes contribuyen de manera más significativa.
#         * La estabilidad del crecimiento sugiere cohortes bien gestionadas y con estrategias efectivas de retención y adquisición.
#
# ## Conclusiones:
#
# * Cohortes Clave:
#     * Cohortes de junio a septiembre de 2020 son críticas, dado su alto impacto en ingresos y transacciones acumuladas.
#     * Sería clave identificar qué estrategias impulsaron este éxito para replicarlas en cohortes futuras.
#
# * Potencial de Cohortes Recientes:
# Aunque la cohorte de noviembre de 2020 muestra menores contribuciones, su bajo tiempo de vida puede justificarlo. Se sugiere monitoreo constante y estrategias de retención.
#
# * Estrategias para Optimización:
# Incrementar esfuerzos en cohortes iniciales con bajo rendimiento para aprovechar clientes existentes.
# Diseñar estrategias para acelerar la contribución de cohortes más recientes, asegurando continuidad en el crecimiento.
#
# * Consideraciones:
# Podríamos estudiar los factores que impulsaron el rendimiento superior de cohortes clave (junio a septiembre de 2020). O implementar campañas personalizadas basadas en comportamientos históricos para aumentar transacciones y ticket promedio.
